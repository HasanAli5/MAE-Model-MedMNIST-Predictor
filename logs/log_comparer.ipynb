# %%
import matplotlib.pyplot as plt
import pandas as pd
import time 

log_file_path_1 = "logs/v3_training_cross_predictor_v2_log_1787065876.0654662.csv"
log_file_path_2 = "logs/v3_training_cross_reducer_hybrid_eyes_log_1787004755.871617.csv"

dataframe_1 = pd.read_csv(log_file_path_1)
dataframe_2 = pd.read_csv(log_file_path_2)

plt.plot(dataframe_1["epoch"],dataframe_1["train_loss"]-dataframe_2["train_loss"])

plt.plot(dataframe_1["epoch"],dataframe_1["val_loss"]-dataframe_2["val_loss"])
#plt.plot(dataframe_2["epoch"],)
plt.title
plt.xlabel("Epochs")
plt.ylabel("Loss Delta")
plt.show()
plt.close()
