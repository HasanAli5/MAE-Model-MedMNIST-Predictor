# %%
import matplotlib.pyplot as plt
import pandas as pd
import time 

log_file_path = "logs/v3_training_cross_predictor_v2_log_1787065876.0654662.csv"

dataframe = pd.read_csv(log_file_path)

plt.plot(dataframe["epoch"],dataframe["train_delta"])
plt.plot(dataframe["epoch"],dataframe["val_delta"])
plt.title
plt.xlabel("Epochs")
plt.ylabel("Loss Delta")
plt.show()
plt.close()
